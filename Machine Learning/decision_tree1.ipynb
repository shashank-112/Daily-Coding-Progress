# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('his code/salaries.csv')
data.head(2)
# Out:
#   company              job     degree  salary_more_then_100k
# 0  google  sales executive  bachelors                      0
# 1  google  sales executive    masters                      0

# %%
x_pop = pd.get_dummies(data.iloc[:,0:3]).astype(int)
x_pop.drop(columns=['company_abc pharma', 'job_computer programmer', 'degree_bachelors'], axis='columns',inplace=True)
x_pop.head(2)
# Out:
#    company_facebook  company_google  job_business manager  \
# 0                 0               1                     0
# 1                 0               1                     0
#
#    job_sales executive  degree_masters
# 0                    1               0
# 1                    1               1

# %%
data = pd.concat([x_pop,data['salary_more_then_100k']], axis='columns')
data.head(2)
# Out:
#    company_facebook  company_google  job_business manager  \
# 0                 0               1                     0
# 1                 0               1                     0
#
#    job_sales executive  degree_masters  salary_more_then_100k
# 0                    1               0                      0
# 1                    1               1                      0

# %%
data.iloc[:,5:6]
# Out:
#     salary_more_then_100k
# 0                       0
# 1                       0
# 2                       1
# 3                       1
# 4                       0
# 5                       1
# 6                       0
# 7                       0
# 8                       0
# 9                       1
# 10                      1
# 11                      1
# 12                      1
# 13                      1
# 14                      1
# 15                      1

# %%
from sklearn.linear_model import LogisticRegression
obj = LogisticRegression()
obj.fit(data.iloc[:,0:5],data.iloc[:,5:6])
# Out:
# C:\Users\madhu sushma\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
m = obj.coef_
b = obj.intercept_
print(m[0][0],b)
# Out:
# 1.2872309834056082 [-0.20941968]

# %%
def f(m,x,b,i):
    return 1 / (1 + np.exp(-(m[0][i] * x + -0.20941968)))

# %%
for i in range(5):
    plt.plot(thex,f(m,thex,b,i))
