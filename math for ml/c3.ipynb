# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import torch
# Out:
# WARNING:tensorflow:From C:\Users\madhu sushma\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
nois = np.random.normal(0,0.2,8)
y = tf.constant([i+.0 for i in range(1,9)])
y = y+nois
x = tf.constant([i for i in range(8,0,-1)])

# %%
y = [1.2111895, 2.224515, 2.9473615, 4.1407113, 4.6413918, 5.9247375, 6.5351357, 7.8028946]
x = [8, 7, 6, 5, 4, 3, 2, 1]
plt.figure(figsize=(5, 3.5))
plt.plot(x,y)

# %%
def regression(x,m,b):
    return m*x+b

# %%
m = torch.tensor([.9]).requires_grad_()
b = torch.tensor([0.1]).requires_grad_()

# %%
def regression(x,m,b):
    return m*x+b
y = torch.tensor([1.86, 1.31, .62, .33, .09, -.67, -1.23, -1.37])
x = torch.tensor([0, 1, 2, 3, 4, 5, 6, 7.])

m = torch.tensor([.9]).requires_grad_()
b = torch.tensor([0.1]).requires_grad_()

y1 = regression(x[7],m,b)
loss = torch.mean((y1 - y[7]) ** 2)

# Compute gradients
loss.backward()
m.grad,b.grad
# Out:
# (tensor([108.7800]), tensor([15.5400]))

# %%
cval = 2*x[7]*(regression(x[7],m,b)-y[7])

# %%
cval
# Out:
# tensor([108.7800], grad_fn=<MulBackward0>)

# %%
plt.figure(figsize=(5, 3.5))
plt.plot(x,y)
plt.plot([x1,y2],[x2,y3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 plt.figure(figsize=(5, 3.5))
#       2 plt.plot(x,y)
# ----> 3 plt.plot([x1,y2],[x2,y3])
#
# NameError: name 'x1' is not defined

# %%
x1,x2,y2,y3 = 1, regression(1,m.grad,b.grad),8,regression(8,m.grad,b.grad)

# %%
print(x1,y2,x2,y3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(x1,y2,x2,y3)
#
# NameError: name 'x2' is not defined

# %%
m.grad,b.grad
# Out:
# (tensor(42.6050), tensor(8.0650))
